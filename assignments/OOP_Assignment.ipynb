# %% [markdown]
# # OOP Assignment
#
# Python programs demonstrating Object-Oriented Programming concepts.

# %% [markdown]
# ### Q1. Write a Python program to create a class representing a **Circle**. Include methods to calculate its area and perimeter.

# %%
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius
    
    def area(self):
        return math.pi * self.radius ** 2
    
    def perimeter(self):
        return 2 * math.pi * self.radius
    
    def display(self):
        print(f"Circle with radius: {self.radius}")
        print(f"Area: {self.area():.2f}")
    
a = Circle(5)
a.display()
# Out:
# Circle with radius: 5
# Area: 78.54

# %% [markdown]
# ### Q2. Write a Python program to create a **Person** class. Include attributes like name, country and date of birth. Implement a method to determine the person's age.

# %%
from datetime import date

class Person:
    def __init__(self, name, country, date_of_birth):
        self.name = name
        self.country = country
        self.date_of_birth = date_of_birth
    
    def age(self):
        today = date.today()
        age = today.year - self.date_of_birth.year
        if (today.month, today.day) < (self.date_of_birth.month, self.date_of_birth.day):
            age -= 1
        return age
    
    def display(self):
        print(f"Name: {self.name}")
        print(f"Country: {self.country}")
        print(f"Date of Birth: {self.date_of_birth}")
        print(f"Age: {self.age()}")

# Example usage
person1 = Person("John Doe", "USA", date(2002,11,16))
person1.display()
# Out:
# Name: John Doe
# Country: USA
# Date of Birth: 2002-11-16
# Age: 23

# %% [markdown]
# ### Q3. Write a Python program to create a **Calculator** class. Include methods for basic arithmetic operations.

# %%
class Calculator:
    def add(self,a,b):
        return a + b
    def sub(self,a,b):
        return a - b
    def mul(self,a,b):
        return a * b 
    def div(self,a,b):
        if a == 0:
            return "Division is not possible"        
        else:
            return a / b
calc =  Calculator()

print(f"Addition : {calc.add(10,5)}")
print(f"Subtraction : {calc.sub(55,78)}")
print(f"Multiplication: {calc.mul(55,95)}")
print(f"Division: {calc.div(6,2)}")
# Out:
# Addition : 15
# Subtraction : -23
# Multiplication: 5225
# Division: 3.0

# %% [markdown]
# ### Q4. Write a Python program to create a class that represents a **Shape**. Include methods to calculate its area and perimeter. Implement subclasses for different shapes like Circle, Triangle, and Square.

# %%
# Write your code here

import math 
class Shape:
    def area(self):
        pass
    def perimerter(self):
        pass
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    
    def area(self):
        return math.pi * self.radius
class Square(Shape):
    def __init__(self,side_length):
        self.side_length = side_length
    def area(self):
        return self.side_length**2
    def perimeter(self):
        return 4*self.side_length

class Triangle(Shape):
    def __init__(self,side_a,side_b,side_c):
        self.side_a = side_a
        self.side_b = side_b
        self.side_c = side_c
        
    def area(self):
        s = (self.side_a + self.side_b + self.side_c)/2
        if s > self.side_a and s > self.side_b and s > self.side_c:
            return math.sqrt( s * (s - self.side_a) * (s-self.side_b)* (s-self.side_c))
        else:
            return "Invalid triangle side"

    def perimeter(self):
        return self.side_a + self.side_b + self.side_c


        
        
if __name__ == "__main__":
    print("\n ---circle---")
    circle = Circle(5)
    print(f"Area: {circle.area()}")
    # print(f"perimeter: {circle.perimeter()}")

    print("\n -----square -----")

    square = Square(4)
    print(f"Area: {square.area()}")
    print(f"Perimeter: {square.perimeter()}")


    print("\n ---Triangle ---")
    triangle = Triangle(3,4,5)
    print(f"Area: {triangle.area()}")
    print(f"Perimeter: {triangle.perimeter()}")
# Out:
#  ---circle---
# Area: 15.707963267948966
#
#  -----square -----
# Area: 16
# Perimeter: 16
#
#  ---Triangle ---
# Area: 6.0
# Perimeter: 12

# %% [markdown]
# ### Q5. Write a Python program to create a class representing a **Binary Search Tree**. Include methods for inserting and searching for elements.

# %%
# Write your code here
class Node:
    def __init__(self,value):
        self.value =value
        self.left = None
        self.right = None

class BinarySearchTree:
    def __init__(self):
        self.root = None

    def insert(self,value):
        if self.root is None:
            self.root = Node(value)

        else:
            self._insert_recursive(self.root,value)
    def _insert_recursive(self,current_node,value):
        if value < current_node.value:
            if current_node.left is None:
                current_node.left = Node(value)
            else:
                self._insert_recursive(current_node.left,value)
        elif value > current_node.value:
            if current_node.right is None:
                current_node.right = Node(value)
            else:
                print(f"Value {value} is already in the tree" )

# %% [markdown]
# ### Q6. Write a Python program to create a class representing a **Stack** data structure. Include methods for pushing and popping elements.

# %%
# Write your code here

# %% [markdown]
# ### Q7. Write a Python program to create a class representing a **Linked List** data structure. Include methods for displaying linked list data, inserting and deleting nodes.

# %%
# Write your code here

# %% [markdown]
# ### Q8. Write a Python program to create a class representing a **Shopping Cart**. Include methods for adding and removing items, and calculating the total price.

# %%
# Write your code here

# %% [markdown]
# ### Q9. Write a Python program to create a class representing a **Stack** data structure. Include methods for pushing, popping and displaying elements.

# %%
# Write your code here

# %% [markdown]
# ### Q10. Write a Python program to create a class representing a **Queue** data structure. Include methods for enqueueing and dequeueing elements.

# %%
# Write your code here

# %% [markdown]
# ### Q11. Write a Python program to create a **BankAccount** class with the following:
# - Attributes: `accountNumber`, `name`, `balance`
# - Constructor with parameters: `accountNumber`, `name`, `balance`
# - `Deposit()` method to manage deposits
# - `Withdrawal()` method to manage withdrawals
# - `bankFees()` method to apply 5% bank fee on balance
# - `display()` method to show account details

# %%
# Write your code here

# %% [markdown]
# ### Q12. Build a **Flashcard** quiz using a class in Python.
# - Create a class `FlashCard`
# - Initialize a dictionary of fruits (name → color) using `__init__()`
# - Randomly choose a fruit and prompt the user for its color
# - Print Correct/Wrong and ask if they want to play again
#
# Sample Output:
# ```
# welcome to fruit quiz
# What is the color of Strawberries
# pink
# Correct answer
# Enter 0, if you want to play again: 0
# ```

# %%
# Write your code here

# %% [markdown]
# ### Q13. **TechWorld** instructor allocation system.
#
# Eligibility criteria:
# - Experience > 3 years → avg feedback ≥ 4.5
# - Experience ≤ 3 years → avg feedback ≥ 4.0
# - Must possess the required technology skill
#
# Implement the class with:
# - All instance variables private, methods public
# - `technology_skill` as a list
# - `check_eligibility()` → returns True/False
# - `allocate_course(technology)` → returns True/False
# - Use setter methods to initialize instance variables

# %%
# Write your code here

# %% [markdown]
# ### Q14. Write a program using `datetime` module within a class. Enter manufacturing date and expiry date of a product. Display the years, months and days left for expiry.

# %%
# Write your code here

# %% [markdown]
# ### Q15. **University Admission** system.
#
# Data valid if:
# - Age > 20
# - Marks between 0 and 100 (inclusive)
#
# Student qualifies if data is valid AND marks ≥ 65.
#
# Write a Python program to represent students seeking admission.

# %%
# Write your code here

# %% [markdown]
# ### Q16. **Ice-Cream Scoops and Bowl** shop.
# - `Scoop` class: public `flavor`, private `price`, getter/setter for price, `sold()` method
# - `Bowl` class: private `scoop_list`, `add_scoops(*scoops)` method, `display()` method (shows each flavor/price and total), `sold()` method

# %%
# Write your code here

# %% [markdown]
# ### Q17. Create a **Bus** child class that inherits from `Vehicle`.
# - Default fare = seating capacity × 100
# - Bus adds 10% maintenance charge on top
# - Bus seating capacity = 50 → expected fare = ₹5500
# - Override the `fare()` method in Bus class

# %%
# Write your code here

# %% [markdown]
# ### Q18. Write a Python class **Employee** with:
# - Attributes: `emp_id`, `emp_name`, `emp_salary`, `emp_department`
# - `assign_department(dept)` — change department
# - `print_employee_details()` — print all details
# - `calculate_emp_salary(salary, hours_worked)` — if hours > 50, add overtime:
#   - overtime = hours_worked - 50
#   - overtime amount = overtime × (salary / 50)
#
# Sample data: `("ADAMS", "E7876", 50000, "ACCOUNTING")`

# %%
# Write your code here

# %% [markdown]
# ### Q19. Write a Python class **Restaurant** with:
# - Attributes: `menu_items`, `book_table`, `customer_orders`
# - `add_item_to_menu(item, price)`
# - `book_tables(customer, table_no)`
# - `customer_order(customer, items)`
# - Print menu, reservations, and orders
#
# Use dictionaries and lists to store data.

# %%
# Write your code here

# %% [markdown]
# ### Q20. Write a Python class **BankAccount** with attributes `account_number`, `balance`, `date_of_opening`, `customer_name`, and methods `deposit()`, `withdraw()`, and `check_balance()`.

# %%
# Write your code here

# %% [markdown]
# ### Q21. Write a Python class **Inventory** with attributes `item_id`, `item_name`, `stock_count`, `price`, and methods `add_item()`, `update_item()`, and `check_item_details()`.

# %%
# Write your code here
